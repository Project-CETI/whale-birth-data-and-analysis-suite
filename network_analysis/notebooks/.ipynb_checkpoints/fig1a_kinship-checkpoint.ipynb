# %% [markdown]
# # Social network from legacy data

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb
import cv2
import distinctipy
import matplotlib.patches as patches

sys.path.append("../scripts/")

#from Segmentations import Segmentations
#from Segmentations import scale_image

sb.set_theme(style="ticks", context="paper")

results_dir = "../results/kinship/"
data_dir = "../data/kinship/"

Path(results_dir).mkdir(parents=True, exist_ok=True)
Path(data_dir).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Kinship

# %%
df_related = pd.read_csv(f"{data_dir}Relatedness Individuals - Unit A only.csv", index_col=0)

# drop 1st col and row with whales id
df_related = df_related.dropna()
df_related = df_related.drop("Unnamed: 1", axis=1)

df_related
# Out:
#              Atwood  Handmaid  Lady Oracle  Rounder  Soursop  Fruit Salad  \
# Atwood       1.0000    0.0000       0.0000   0.0000   0.0000       0.0000
# Handmaid     0.1932    1.0000       0.0000   0.0000   0.0000       0.0000
# Lady Oracle  0.4951    0.4806       1.0000   0.0000   0.0000       0.0000
# Rounder      0.3984    0.3394       0.5488   1.0000   0.0000       0.0000
# Soursop     -0.0689   -0.1231      -0.1464   0.0029   1.0000       0.0000
# Fruit Salad -0.0665   -0.1057      -0.2067  -0.0625   0.5164       1.0000
# Oryx        -0.0222   -0.0992      -0.1061  -0.1057   0.1185       0.4519
# Allan        0.1902    0.2449       0.5720   0.3514  -0.1195      -0.0473
# Snow         0.2011    0.0895       0.0535   0.1146   0.0588       0.4011
# ATW calf     0.4762   -0.1062       0.0760   0.2010  -0.0167      -0.1042
# Crake        0.0683   -0.0989      -0.2177  -0.0054   0.3442       0.4377
# Aurora       0.4421    0.4430       0.5071   0.5016   0.0665      -0.0521
#
# ...

# %%
df_related.index
# Out:
# Index(['Atwood', 'Handmaid', 'Lady Oracle', 'Rounder', 'Soursop',
#        'Fruit Salad', 'Oryx', 'Allan', 'Snow', 'ATW calf', 'Crake', 'Aurora'],
#       dtype='object')

# %%
sb.heatmap(df_related.clip(upper=1), cmap="coolwarm", center=0)
# Out:
# <Axes: >

# %%
adj = df_related.values + df_related.values.T
adj = adj - np.diag(np.diag(adj))

# %%
sb.heatmap(adj, cmap="coolwarm", center=0)
# Out:
# <Axes: >

# %%
long_form_df = df_related.reset_index().melt(
    id_vars="index", var_name="col", value_name="value"
)

long_form_df = long_form_df.dropna()
long_form_df = long_form_df.loc[~long_form_df['col'].str.startswith('Unnamed')]


# Remove rows where index equals col (self-loop)
long_form_df = long_form_df[long_form_df['index'] != long_form_df['col']]

# remove upper triangle of sym matrix
long_form_df = long_form_df[long_form_df["value"] != 0]

# %%
long_form_df
# Out:
#            index       col   value
# 1       Handmaid    Atwood  0.1932
# 2    Lady Oracle    Atwood  0.4951
# 3        Rounder    Atwood  0.3984
# 4        Soursop    Atwood -0.0689
# 5    Fruit Salad    Atwood -0.0665
# ..           ...       ...     ...
# 106        Crake      Snow  0.2289
# 107       Aurora      Snow  0.1068
# 118        Crake  ATW calf  0.3213
# 119       Aurora  ATW calf  0.1298
# 131       Aurora     Crake  0.0479
#
# [66 rows x 3 columns]

# %%
weighted_edges = [tuple(x) for x in long_form_df.to_records(index=False)]

# %%
import xgi

# %%
H = xgi.Hypergraph()
H.add_weighted_edges_from(weighted_edges)

# %%
fig, ax = plt.subplots(figsize=(7, 5))

H = xgi.Hypergraph()
H.add_weighted_edges_from(weighted_edges)

pos = xgi.circular_layout(H)

ax, cols = xgi.draw_hyperedges(
    H,
    pos=pos,
    dyad_lw=np.abs(H.edges.attrs("weight").aslist()),
    dyad_color=H.edges.attrs("weight").asdict(),
    dyad_color_cmap="coolwarm",
    dyad_vmin=-0.6,
    dyad_vmax=0.6,
)

xgi.draw_nodes(H, pos=pos, node_labels=True, node_size=20)

plt.colorbar(cols[0], label="kinship")

plt.savefig(f"{results_dir}kinship_network_full.png", bbox_inches="tight", facecolor="w")

# %% [markdown]
# ### threshold for visual clarity

# %%
threshold = 0.15

long_form_thresholded_df = long_form_df[long_form_df["value"] >= threshold]

weighted_edges_thresh = [tuple(x) for x in long_form_thresholded_df.to_records(index=False)]

H_thresh = xgi.Hypergraph()
H_thresh.add_weighted_edges_from(weighted_edges_thresh)

dead_whales = ["Crake", "Oryx", "Handmaid", "ATW calf"]
H_thresh.remove_nodes_from(dead_whales)

# %%
import numpy as np

def generate_two_circle_positions(group1_nodes, group2_nodes, radius=5, separation=10):
    """
    Generates positions for two groups of nodes arranged in separate circles.

    Parameters:
    - group1_nodes (list): List of node names for the first group.
    - group2_nodes (list): List of node names for the second group.
    - radius (float): Radius of the circles.
    - separation (float): Horizontal distance between the two circles.

    Returns:
    - dict: Dictionary of node positions.
    """
    positions = {}
    n = len(group1_nodes)
    m = len(group2_nodes)
    
    # First circle: group1_nodes
    for i, node in enumerate(group1_nodes):
        angle = 2 * np.pi * i / n
        x = radius * np.cos(angle) - separation / 2
        y = radius * np.sin(angle)
        positions[node] = (x, y)
    
    # Second circle: group2_nodes
    for i, node in enumerate(group2_nodes):
        angle = 2 * np.pi * i / m
        x = radius * np.cos(angle) + separation / 2
        y = radius * np.sin(angle)
        positions[node] = (x, y)
    
    return positions

# Example usage
group1_nodes = ['A1', 'A2', 'A3', 'A4', 'A5']
group2_nodes = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6']

positions = generate_two_circle_positions(group1_nodes, group2_nodes)

print(positions)
# Out:
# {'A1': (0.0, 0.0), 'A2': (-3.4549150281252627, 4.755282581475767), 'A3': (-9.045084971874736, 2.9389262614623664), 'A4': (-9.045084971874738, -2.938926261462365), 'A5': (-3.4549150281252636, -4.755282581475768), 'B1': (10.0, 0.0), 'B2': (7.5, 4.330127018922193), 'B3': (2.500000000000001, 4.330127018922194), 'B4': (0.0, 6.123233995736766e-16), 'B5': (2.499999999999998, -4.330127018922192), 'B6': (7.5, -4.330127018922193)}

# %%
group1 = ["Atwood", "Lady Oracle", "Rounder", "Allan", "Aurora"]
group2 = ["Soursop", "Fruit Salad", "Snow"]
pos_test = generate_two_circle_positions(group1, group2, radius=3, separation=15)

# %%
pos_test
# Out:
# {'Atwood': (-4.5, 0.0),
#  'Lady Oracle': (-6.572949016875158, 2.8531695488854605),
#  'Rounder': (-9.927050983124841, 1.7633557568774196),
#  'Allan': (-9.927050983124843, -1.7633557568774192),
#  'Aurora': (-6.5729490168751585, -2.853169548885461),
#  'Soursop': (10.5, 0.0),
#  'Fruit Salad': (6.000000000000001, 2.598076211353316),
#  'Snow': (5.999999999999998, -2.598076211353315)}

# %%
pos
# Out:
# {'Handmaid': array([1., 0.]),
#  'Atwood': array([0.8660254, 0.5      ]),
#  'Lady Oracle': array([0.5      , 0.8660254]),
#  'Rounder': array([6.123234e-17, 1.000000e+00]),
#  'Soursop': array([-0.5      ,  0.8660254]),
#  'Fruit Salad': array([-0.8660254,  0.5      ]),
#  'Oryx': array([-1.0000000e+00,  1.2246468e-16]),
#  'Allan': array([-0.8660254, -0.5      ]),
#  'Snow': array([-0.5      , -0.8660254]),
#  'ATW calf': array([-1.8369702e-16, -1.0000000e+00]),
#  'Crake': array([ 0.5      , -0.8660254]),
#  'Aurora': array([ 0.8660254, -0.5      ])}

# %%
fig, ax = plt.subplots(figsize=(4, 3) , layout="constrained")

#pos = xgi.barycenter_kamada_kawai_layout(H_thresh)
pos = xgi.barycenter_spring_layout(H_thresh, seed=20)
#pos = xgi.circular_layout(H_thresh)
pos = pos_test
# rotate
#pos = xgi.pca_transform(pos, -85)

ax, cols = xgi.draw_hyperedges(
    H_thresh,
    pos=pos,
    #dyad_lw=np.abs(H_thresh.edges.attrs("weight").aslist()),
    dyad_color=H_thresh.edges.attrs("weight").asdict(),
    dyad_color_cmap="Reds",
)

pos_ref = pos

xgi.draw_nodes(H_thresh, pos=pos, node_labels=False, node_size=10, clip_on_nodes=False)

pos_labels = {key: [x+0.05,y] for key, (x,y) in pos.items()}
xgi.draw_node_labels(H_thresh, pos=pos_labels, node_labels=True, 
                     horizontalalignment_nodes="left", verticalalignment_nodes="bottom", clip_on_nodes=False)

ax.set_aspect("equal")

plt.colorbar(cols[0], label="kinship", shrink=0.5)

plt.savefig(
    f"{results_dir}kinship_network_threhsolded_{threshold}.pdf",
    bbox_inches="tight",
    facecolor="w",
)

# %%
results_dir
# Out:
# '../results/kinship/'

# %%
H_thresh.nodes
# Out:
# NodeView(('Atwood', 'Lady Oracle', 'Rounder', 'Allan', 'Snow', 'Aurora', 'Fruit Salad', 'Soursop'))

# %% [markdown]
# ## Association

# %% [markdown]
# ### Raw associations

# %%
df_ided = pd.read_csv(f"{data_dir}IDed Unit A only.csv")
df_ided
# Out:
#          Roll                 Filename             DateTime Encounter  \
# 0     NAMSC04       IFAW-1996-DO-08-30  19-01-1996 09:30:00       NaN
# 1     NAMSC04  SWF-1999-V2-2802-211657  01-01-1999 00:00:00       NaN
# 2     CARIB05          20050224_124755  24-02-2005 12:47:55        14
# 3     CARIB05          20050224_125726  24-02-2005 12:57:26        14
# 4     CARIB05          20050224_125738  24-02-2005 12:57:38        14
# ...       ...                      ...                  ...       ...
# 7273     CS19       20190331_153714a-2  31-03-2019 15:37:14        50
# 7274     CS19       20190331_153714b-2  31-03-2019 15:37:14        50
# 7275     CS19       20190331_153714c-2  31-03-2019 15:37:14        50
# 7276     CS19       20190331_153714d-2  31-03-2019 15:37:14        50
# 7277     CS19       20190331_153715a-2  31-03-2019 15:37:15        50
#
#           Cluster Suckling Link  Males Adults Calves  Part Class  \
# ...

# %% [markdown]
# ### Precomputed association matrices

# %%
sheet_names = pd.ExcelFile(f"{data_dir}Unit A Association Matrices.xlsx").sheet_names
sheet_names
# Out:
# ['SR-2hr',
#  'SR-2hr-gregariousness',
#  'SR-Day',
#  'SR-Day-Gregariousness',
#  'HWI-2hr',
#  'HWI-2hr-gregariousness',
#  'HWI-Day',
#  'HWI-Day-Gregariousness']

# %%
i = 0
df_association = pd.read_excel(
    f"{data_dir}Unit A Association Matrices.xlsx",
    index_col=1,
    skiprows=1,
    sheet_name=sheet_names[i],
)

# drop 1st col and row with whales id
df_association = df_association.drop("Unnamed: 0", axis=1) # this column tells us who is dead, may be useful
df_association = df_association.dropna()
df_association = df_association.drop("Unnamed: 2", axis=1)

#df_association

# %%
adj = df_association.values
adj = adj - np.diag(np.diag(adj)) # set diagonal to zero

sb.heatmap(adj, cmap="coolwarm", center=0)
# Out:
# <Axes: >

# %%
sheet_names
# Out:
# ['SR-2hr',
#  'SR-2hr-gregariousness',
#  'SR-Day',
#  'SR-Day-Gregariousness',
#  'HWI-2hr',
#  'HWI-2hr-gregariousness',
#  'HWI-Day',
#  'HWI-Day-Gregariousness']

# %%
fig, axs = plt.subplots(4, 2, figsize=(7, 9), sharex=True, sharey=True, layout="constrained")

for i, sheet in enumerate(sheet_names):
    
    ax = axs.flatten()[i]
    
    df_association = pd.read_excel(
        f"{data_dir}Unit A Association Matrices.xlsx",
        index_col=1,
        skiprows=1,
        sheet_name=sheet,
    )

    # drop 1st col and row with whales id
    df_association = df_association.drop("Unnamed: 0", axis=1) # this column tells us who is dead, may be useful
    df_association = df_association.dropna()
    df_association = df_association.drop("Unnamed: 2", axis=1)
    
    adj = df_association.values
    adj = adj - np.diag(np.diag(adj)) # set diagonal to zero

    #sb.heatmap(adj, cmap="Blues", ax=ax, square=True)
    ax.set_title(sheet, weight="bold")
    
    long_form_df = df_association.reset_index().melt(
    id_vars="index", var_name="col", value_name="value"
    )

    long_form_df = long_form_df.dropna()
    long_form_df = long_form_df.loc[~long_form_df['col'].str.startswith('Unnamed')]


    # Remove rows where index equals col (self-loop)
    long_form_df = long_form_df[long_form_df['index'] != long_form_df['col']]

    # remove upper triangle of sym matrix (not ordered, but remove duplicates)
    long_form_df = long_form_df[long_form_df["index"] > long_form_df["col"] ]
    
    # threshold weights
    threshold = 0.1 if (i % 2 == 0) else 1 
    long_form_thresholded_df = long_form_df[long_form_df["value"] >= threshold]
    
    weighted_edges = [tuple(x) for x in long_form_thresholded_df.to_records(index=False)]
    #weighted_edges = [tuple(x) for x in long_form_df.to_records(index=False)]

    H = xgi.Hypergraph()
    H.add_weighted_edges_from(weighted_edges)

    #pos = xgi.circular_layout(H)
    pos = xgi.barycenter_kamada_kawai_layout(H)

    ax, cols = xgi.draw_hyperedges(
        H,
        pos=pos,
        ax=ax,
        dyad_lw=np.abs(H.edges.attrs("weight").aslist()),
        dyad_color=H.edges.attrs("weight").asdict(),
        dyad_color_cmap="Reds",
        #dyad_vmin=-0.6,
        #dyad_vmax=0.6,
    )

    xgi.draw_nodes(H, ax=ax, pos=pos, node_labels=True, node_size=1)

    plt.colorbar(cols[0], label="association")
    
plt.subplots_adjust(wspace=0.4)

#plt.savefig(f"{results_dir}association_matrices.png", bbox_inches="tight", facecolor="w", dpi=250)

plt.savefig(f"{results_dir}association_matrices_networks_thresh.png", bbox_inches="tight", facecolor="w", dpi=250)
# Out:
# /tmp/ipykernel_164244/658078501.py:67: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(wspace=0.4)

# %%
sheet_names
# Out:
# ['SR-2hr',
#  'SR-2hr-gregariousness',
#  'SR-Day',
#  'SR-Day-Gregariousness',
#  'HWI-2hr',
#  'HWI-2hr-gregariousness',
#  'HWI-Day',
#  'HWI-Day-Gregariousness']

# %%
df_association = pd.read_excel(
    f"{data_dir}Unit A Association Matrices.xlsx",
    index_col=1,
    skiprows=1,
    sheet_name='HWI-2hr',
)

# drop 1st col and row with whales id
df_association = df_association.drop("Unnamed: 0", axis=1) # this column tells us who is dead, may be useful
df_association = df_association.dropna()
df_association = df_association.drop("Unnamed: 2", axis=1)

adj = df_association.values
adj = adj - np.diag(np.diag(adj)) # set diagonal to zero

#sb.heatmap(adj, cmap="Blues", ax=ax, square=True)
ax.set_title(sheet, weight="bold")

long_form_df = df_association.reset_index().melt(
id_vars="index", var_name="col", value_name="value"
)

long_form_df = long_form_df.dropna()
long_form_df = long_form_df.loc[~long_form_df['col'].str.startswith('Unnamed')]


# Remove rows where index equals col (self-loop)
long_form_df = long_form_df[long_form_df['index'] != long_form_df['col']]

# remove upper triangle of sym matrix (not ordered, but remove duplicates)
long_form_df = long_form_df[long_form_df["index"] > long_form_df["col"] ]

# threshold weights
threshold = 0. #if (i % 2 == 0) else 1 
long_form_thresholded_df = long_form_df[long_form_df["value"] >= threshold]

weighted_edges = [tuple(x) for x in long_form_thresholded_df.to_records(index=False)]
#weighted_edges = [tuple(x) for x in long_form_df.to_records(index=False)]

H = xgi.Hypergraph()
H.add_weighted_edges_from(weighted_edges)

H.remove_nodes_from(dead_whales)

# %%
fig, ax = plt.subplots(figsize=(4.5, 3), layout="constrained")

#pos = xgi.barycenter_kamada_kawai_layout(H_thresh)
pos = xgi.barycenter_spring_layout(H, seed=6)
#pos = xgi.circular_layout(H_thresh)

# rotate
#pos = xgi.pca_transform(pos, -65)

group1 = ["Atwood", "LadyO", "Rounder", "Allan", "Aurora", "Accra"]
group2 = ["Soursop", "Fruit", "Snow"]
pos_test = generate_two_circle_positions(group1, group2, radius=3, separation=15)
pos = pos_test

ax, cols = xgi.draw_hyperedges(
    H,
    pos=pos,
    #dyad_lw=np.abs(H_thresh.edges.attrs("weight").aslist()),
    dyad_color=H.edges.attrs("weight").asdict(),
    dyad_color_cmap="Blues",
)

xgi.draw_nodes(H, pos=pos, node_labels=False, node_size=10, clip_on_nodes=False)

pos_labels = {key: [x+0.03,y] for key, (x,y) in pos.items()}
xgi.draw_node_labels(H, pos=pos_labels, node_labels=True, 
                     horizontalalignment_nodes="left", verticalalignment_nodes="bottom", clip_on_nodes=False)

ax.set_aspect("equal")

plt.colorbar(cols[0], label="association", shrink=0.5)

plt.savefig(
    f"{results_dir}association_network_threhsolded_{threshold}.pdf",
    bbox_inches="tight",
    facecolor="w",
)

# %%
import networkx as nx

# %%
weighted_edges
# Out:
# [('LadyO', 'Atwood', 0.17),
#  ('Rounder', 'Atwood', 0.28),
#  ('Aurora', 'Atwood', 0.25),
#  ('Atwood', 'ATW calf', 0.21),
#  ('Rounder', 'ATW calf', 0.16),
#  ('Crake', 'ATW calf', 0.27),
#  ('Allan', 'ATW calf', 0.13),
#  ('Rounder', 'LadyO', 0.34),
#  ('Soursop', 'Fruit', 0.32),
#  ('Snow', 'Fruit', 0.14),
#  ('Snow', 'Oryx', 0.2),
#  ('Soursop', 'Crake', 0.11),
#  ('Fruit', 'Crake', 0.13),
#  ('Oryx', 'Crake', 0.41),
#  ('Atwood', 'Allan', 0.16),
#  ('LadyO', 'Allan', 0.29),
#  ('Rounder', 'Allan', 0.19),
#  ('Aurora', 'Allan', 0.13),
#  ('Soursop', 'Snow', 0.11),
#  ('Atwood', 'Accra', 0.1),
#  ('Rounder', 'Accra', 0.28),
#  ('Aurora', 'Accra', 0.32),
#  ('LadyO', 'Aurora', 0.42),
#  ('Rounder', 'Aurora', 0.41)]

# %%
G_assoc = nx.Graph()

threshold_assoc = 0.1
weighted_edges_thresholded = [(u, v, w) for (u, v, w) in weighted_edges if w >= threshold_assoc]

# Add edges with weights
G_assoc.add_weighted_edges_from(weighted_edges_thresholded)
G_assoc.remove_nodes_from(dead_whales)

# Optional: draw the graph (requires matplotlib)
import matplotlib.pyplot as plt

pos = nx.spring_layout(G_assoc)
nx.draw_networkx(G_assoc, pos, with_labels=True, node_color='lightblue', edge_color='gray', node_size=150, font_size=10)
plt.show()

# %%
named_ids = list(G_assoc.nodes)
labels_family = [family_membership[i] for i in named_ids]
labels_family
# Out:
# ['left', 'left', 'left', 'left', 'left', 'right', 'right', 'right', 'left']

# %%
named_ids
# Out:
# ['LadyO',
#  'Atwood',
#  'Rounder',
#  'Aurora',
#  'Allan',
#  'Soursop',
#  'Fruit',
#  'Snow',
#  'Accra']

# %%
families = {named_ids[i]: labels_family[i] for i in range(len(named_ids))}
nx.set_node_attributes(G_assoc, families, 'family')

# %% [markdown]
# #### Kinship homophily

# %%
from collections import defaultdict

all_named_whales = ["Atwood", "LadyO", "Rounder", "Allan", "Aurora", "Accra", "Newborn", "Fruit", 
                    "Soursop", "Snow", "Ariel", "YOY"]

family_members = {"left" : ["Atwood", "LadyO", "Rounder", "Allan", "Aurora", "Accra", "Newborn"],
                  "right" : ["Fruit", "Soursop", "Snow", "Ariel", "YOY"]}

age_members = {"calf" : ["Accra", "Newborn", "Ariel", "YOY"],
              "adult" : ["Rounder", "Allan", "Aurora", "Lady Oracle", "Atwood", "Fruit", "Soursop", "Snow"]}

family_membership = defaultdict(lambda: None)
age_membership = defaultdict(lambda: None)

for family, members in family_members.items():
    for member in members:
        family_membership[member] = family

for adult, members in age_members.items():
    for member in members:
        age_membership[member] = adult

#family_membership = {member : family for family, members in family_members.items() for member in members}
family_membership
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'Atwood': 'left',
#              'LadyO': 'left',
#              'Rounder': 'left',
#              'Allan': 'left',
#              'Aurora': 'left',
#              'Accra': 'left',
#              'Newborn': 'left',
#              'Fruit': 'right',
#              'Soursop': 'right',
#              'Snow': 'right',
#              'Ariel': 'right',
#              'YOY': 'right'})

# %%
def nx_adjusted_assortativity(nx_graph, attribute):
    import networkx as nx
    counts, unique = nx_group_fraction(nx_graph, attribute)
    group_map = dict([(unique[i], i) for i in range(len(unique))])

    absolute_mixing_matrix = nx.attribute_mixing_matrix(
        nx_graph, attribute, normalized=True, mapping=group_map)

    counts = counts / np.sum(counts)

    e_line = counts * counts.reshape(len(unique), 1) #- np.diag(counts)
    #print(f"eline")
    #print(f"{e_line}")

    absolute_mixing_matrix = np.divide(absolute_mixing_matrix, e_line)
    absolute_mixing_matrix /= absolute_mixing_matrix.sum()

    sum_ai_bi = np.sum(absolute_mixing_matrix.sum(axis=0) * absolute_mixing_matrix.sum(axis=1))
    sum_eii = np.sum(absolute_mixing_matrix.diagonal())
    adjusted_assortativity = (sum_eii - sum_ai_bi) / (1 - sum_ai_bi)
    return adjusted_assortativity


def nx_group_fraction(nx_graph, attribute):
    nodes_group = [nx_graph.nodes[n][attribute] for n in nx_graph.nodes]
    unique, counts = np.unique(nodes_group, return_counts=True)
    counts, unique = list(zip(*sorted(zip(counts, unique))))
    counts = np.array(counts)
    return counts, unique


def gt_adjusted_assortativity(gt_graph, group_memberships):
    import graph_tool.all as gt
    membership_property = _node_groups(gt_graph, group_memberships)
    unique, counts = np.unique(group_memberships, return_counts=True)
    m, _ = gt.corr_hist(gt_graph, membership_property, membership_property)
    m = np.divide(m, counts.reshape(2, 1)*counts)
    m /= m.sum()
    sum_ai_bi = np.sum(m.sum(axis=0)*m.sum(axis=1))
    sum_eii = np.sum(m.diagonal())
    return (sum_eii - sum_ai_bi)/(1 - sum_ai_bi)


def gt_assortativity(g, group_memberships):
    import graph_tool.all as gt
    return gt.assortativity(g, _node_groups(g, group_memberships))


def _node_groups(g, group_memberships):
    vertex_group = g.new_vertex_property('int')
    for m, v in zip(group_memberships, g.vertices()):
        vertex_group[g.vertex(v)] = m
    return vertex_group

# %%
nx_adjusted_assortativity(G_assoc, attribute="family")
# Out:
# 1.0

# %% [markdown]
# ### Similarity between different graphs

# %%
df_kin = pd.read_csv(f"{data_dir}Relatedness Individuals - Unit A only.csv", index_col=0)

# drop 1st col and row with whales id
df_kin = df_kin.dropna()
df_kin = df_kin.drop("Unnamed: 1", axis=1)

df_kin
# Out:
#              Atwood  Handmaid  Lady Oracle  Rounder  Soursop  Fruit Salad  \
# Atwood       1.0000    0.0000       0.0000   0.0000   0.0000       0.0000
# Handmaid     0.1932    1.0000       0.0000   0.0000   0.0000       0.0000
# Lady Oracle  0.4951    0.4806       1.0000   0.0000   0.0000       0.0000
# Rounder      0.3984    0.3394       0.5488   1.0000   0.0000       0.0000
# Soursop     -0.0689   -0.1231      -0.1464   0.0029   1.0000       0.0000
# Fruit Salad -0.0665   -0.1057      -0.2067  -0.0625   0.5164       1.0000
# Oryx        -0.0222   -0.0992      -0.1061  -0.1057   0.1185       0.4519
# Allan        0.1902    0.2449       0.5720   0.3514  -0.1195      -0.0473
# Snow         0.2011    0.0895       0.0535   0.1146   0.0588       0.4011
# ATW calf     0.4762   -0.1062       0.0760   0.2010  -0.0167      -0.1042
# Crake        0.0683   -0.0989      -0.2177  -0.0054   0.3442       0.4377
# Aurora       0.4421    0.4430       0.5071   0.5016   0.0665      -0.0521
#
# ...

# %%
group1 = ["Atwood", "Lady Oracle", "Rounder", "Allan", "Aurora"]
group2 = ["Soursop", "Fruit Salad", "Snow"]
whales_kin = group1 + group2

df_kin = df_kin.loc[whales_kin, whales_kin]
df_kin
# Out:
#              Atwood  Lady Oracle  Rounder   Allan  Aurora  Soursop  \
# Atwood       1.0000       0.0000   0.0000  0.0000       0   0.0000
# Lady Oracle  0.4951       1.0000   0.0000  0.0000       0   0.0000
# Rounder      0.3984       0.5488   1.0000  0.0000       0   0.0000
# Allan        0.1902       0.5720   0.3514  1.0000       0  -0.1195
# Aurora       0.4421       0.5071   0.5016  0.3481       1   0.0665
# Soursop     -0.0689      -0.1464   0.0029  0.0000       0   1.0000
# Fruit Salad -0.0665      -0.2067  -0.0625  0.0000       0   0.5164
# Snow         0.2011       0.0535   0.1146  0.0282       0   0.0588
#
#              Fruit Salad    Snow
# Atwood            0.0000  0.0000
# Lady Oracle       0.0000  0.0000
# Rounder           0.0000  0.0000
# Allan            -0.0473  0.0000
# Aurora           -0.0521  0.1068
# Soursop           0.0000  0.0000
# Fruit Salad       1.0000  0.0000
# Snow              0.4011  1.0000

# %%
adj_kin = df_kin.values + df_kin.values.T
adj_kin = adj_kin - np.diag(np.diag(adj_kin))

sb.heatmap(adj_kin, cmap="coolwarm", center=0, xticklabels=df_kin.index, yticklabels=df_kin.index)
# Out:
# <Axes: >

# %%
df_association = pd.read_excel(
    f"{data_dir}Unit A Association Matrices.xlsx",
    index_col=1,
    skiprows=1,
    sheet_name='HWI-2hr',
)

# drop 1st col and row with whales id
df_association = df_association.drop("Unnamed: 0", axis=1) # this column tells us who is dead, may be useful
df_association = df_association.dropna()
df_association = df_association.drop("Unnamed: 2", axis=1)

df_association
# Out:
#           Atwood  ATW calf  Handmaid  LadyO   B17  Rounder  Soursop  Fruit  \
# Atwood      1.00      0.21      0.01   0.17  0.00     0.28     0.05   0.07
# ATW calf    0.21      1.00      0.04   0.09  0.00     0.16     0.02   0.04
# Handmaid    0.01      0.04      1.00   0.04  0.00     0.05     0.02   0.04
# LadyO       0.17      0.09      0.04   1.00  0.02     0.34     0.02   0.03
# B17         0.00      0.00      0.00   0.02  1.00     0.01     0.00   0.00
# Rounder     0.28      0.16      0.05   0.34  0.01     1.00     0.04   0.04
# Soursop     0.05      0.02      0.02   0.02  0.00     0.04     1.00   0.32
# Fruit       0.07      0.04      0.04   0.03  0.00     0.04     0.32   1.00
# Oryx        0.05      0.09      0.03   0.00  0.00     0.02     0.07   0.02
# Crake       0.06      0.27      0.04   0.00  0.00     0.01     0.11   0.13
# Allan       0.16      0.13      0.02   0.29  0.00     0.19     0.03   0.01
# ...

# %%
group1 = ["Atwood", "LadyO", "Rounder", "Allan", "Aurora"]#, "Accra"]
group2 = ["Soursop", "Fruit", "Snow"]
whales_assoc = group1 + group2 

df_association = df_association.loc[whales_assoc, whales_assoc]
df_association
# Out:
#          Atwood  LadyO  Rounder  Allan  Aurora  Soursop  Fruit  Snow
# Atwood     1.00   0.17     0.28   0.16    0.25     0.05   0.07  0.06
# LadyO      0.17   1.00     0.34   0.29    0.42     0.02   0.03  0.05
# Rounder    0.28   0.34     1.00   0.19    0.41     0.04   0.04  0.03
# Allan      0.16   0.29     0.19   1.00    0.13     0.03   0.01  0.04
# Aurora     0.25   0.42     0.41   0.13    1.00     0.00   0.01  0.01
# Soursop    0.05   0.02     0.04   0.03    0.00     1.00   0.32  0.11
# Fruit      0.07   0.03     0.04   0.01    0.01     0.32   1.00  0.14
# Snow       0.06   0.05     0.03   0.04    0.01     0.11   0.14  1.00

# %%
# harmonize whale names
df_association.index = whales_kin
df_association.columns = whales_kin
df_association
# Out:
#              Atwood  Lady Oracle  Rounder  Allan  Aurora  Soursop  \
# Atwood         1.00         0.17     0.28   0.16    0.25     0.05
# Lady Oracle    0.17         1.00     0.34   0.29    0.42     0.02
# Rounder        0.28         0.34     1.00   0.19    0.41     0.04
# Allan          0.16         0.29     0.19   1.00    0.13     0.03
# Aurora         0.25         0.42     0.41   0.13    1.00     0.00
# Soursop        0.05         0.02     0.04   0.03    0.00     1.00
# Fruit Salad    0.07         0.03     0.04   0.01    0.01     0.32
# Snow           0.06         0.05     0.03   0.04    0.01     0.11
#
#              Fruit Salad  Snow
# Atwood              0.07  0.06
# Lady Oracle         0.03  0.05
# Rounder             0.04  0.03
# Allan               0.01  0.04
# Aurora              0.01  0.01
# Soursop             0.32  0.11
# Fruit Salad         1.00  0.14
# Snow                0.14  1.00

# %%
adj_assoc = df_association.values
adj_assoc = adj_assoc - np.diag(np.diag(adj_assoc)) # set diagonal to zero

sb.heatmap(adj_assoc, cmap="coolwarm", center=0, xticklabels=df_association.index, yticklabels=df_association.index)
# Out:
# <Axes: >

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(6, 2.5), layout="constrained")


sb.heatmap(adj_kin, cmap="coolwarm", center=0, xticklabels=df_kin.index, yticklabels=df_kin.index, ax=ax1, square=True)

sb.heatmap(adj_assoc, cmap="coolwarm", center=0, xticklabels=df_association.index, yticklabels=df_association.index, ax=ax2, square=True)

ax1.set_title("Kinship", weight="bold")
ax2.set_title("Association", weight="bold")

fig_name = f"kinship_vs_association"
plt.savefig(f"{results_dir}{fig_name}.pdf", dpi=250, bbox_inches="tight", facecolor="w")


plt.show()

# %%
import numpy as np
from scipy.stats import pearsonr

# Example: two pandas DataFrames of same shape
x = adj_kin.flatten()
y = adj_assoc.flatten()

corr, pval = pearsonr(x, y)
print(f'Correlation: {corr:.2f}, p-value: {pval:.2e}')
# Out:
# Correlation: 0.88, p-value: 1.09e-21

# %% [markdown]
# #### Legacy association vs birth data

# %%
import pickle 

# with open('../data/adjacencies_centroid_dist_avg.pkl', 'rb') as fp:
#     adjacency_matrices_avg = pickle.load(fp)

with open('../results/adjacency_matrices_mask_dist.pkl', 'rb') as fp:
    adjacency_matrices_mask_dist = pickle.load(fp)

# %%
vid_numbers = list(adjacency_matrices_mask_dist.keys())
# vid_numbers

# %%
import pickle 

segmentations = {}

for vid_number in vid_numbers:

    file_name = f"../data/{vid_number}_cleaned_with_masks.pkl"
    with open(file_name, "rb") as fp:
        segmentation = pickle.load(fp)

        segmentations[vid_number] = segmentation

# %%
# store results
p_values = dict() 
correlations = dict()

# %%
len(vid_numbers)
# Out:
# 18

# %%
ii = -1
frame = 0
vid_number = vid_numbers[ii] #"1688827660979"
seg = segmentations[vid_number]
whales_dist = [w.title() for w in seg["ids"]]

print(vid_number)

adjs_dist = adjacency_matrices_mask_dist[vid_number] # time series of adjacency matrices (distance)

adj_dist = adjs_dist[frame] # at a given frame
adj_dist_avg = np.nanmean(adjs_dist, axis=0) # averaged over time

# inverse distance matrix
adj_dist_avg_inv = 1 / (adj_dist_avg + 1e-1)
np.fill_diagonal(adj_dist_avg_inv, 0)

sb.heatmap(adj_dist_avg_inv, cmap="coolwarm", center=0, xticklabels=whales_dist, yticklabels=whales_dist)

# print(adj_dist.shape)
# Out:
# 1688841618482_2
# /tmp/ipykernel_101683/4071821475.py:12: RuntimeWarning: Mean of empty slice
#   adj_dist_avg = np.nanmean(adjs_dist, axis=0) # averaged over time
# <Axes: >

# %%
# Convert to DataFrame for easy subsetting
df_dist = pd.DataFrame(adj_dist_avg_inv, index=whales_dist, columns=whales_dist)
df_dist
# Out:
#            Atwood   Soursop     Ariel   Rounder  Yoy     Accra    Aurora  \
# Atwood   0.000000  0.001090  0.001263  0.131148  NaN  0.028974  0.264559
# Soursop  0.001090  0.000000  0.020082  0.001110  NaN  0.001117  0.001256
# Ariel    0.001263  0.020082  0.000000  0.001291  NaN  0.001298  0.001477
# Rounder  0.131148  0.001110  0.001291  0.000000  NaN  0.304776  0.048687
# Yoy           NaN       NaN       NaN       NaN  0.0       NaN       NaN
# Accra    0.028974  0.001117  0.001298  0.304776  NaN  0.000000  0.012878
# Aurora   0.264559  0.001256  0.001477  0.048687  NaN  0.012878  0.000000
# Snow     0.000962  0.036883  0.007876  0.000981  NaN  0.001005  0.001044
# Newborn  0.065663  0.000963  0.001093  0.542725  NaN  0.019203  0.052680
#
#              Snow   Newborn
# Atwood   0.000962  0.065663
# Soursop  0.036883  0.000963
# Ariel    0.007876  0.001093
# Rounder  0.000981  0.542725
# Yoy           NaN       NaN
# Accra    0.001005  0.019203
# Aurora   0.001044  0.052680
# ...

# %%
whales_common = [w for w in whales_kin if w in whales_dist]
whales_common
# Out:
# ['Atwood', 'Rounder', 'Aurora', 'Soursop', 'Snow']

# %%
adj_dist = df_dist.loc[whales_common, whales_common].values

df_dist.loc[whales_common, whales_common]
# Out:
#            Atwood   Rounder    Aurora   Soursop      Snow
# Atwood   0.000000  0.131148  0.264559  0.001090  0.000962
# Rounder  0.131148  0.000000  0.048687  0.001110  0.000981
# Aurora   0.264559  0.048687  0.000000  0.001256  0.001044
# Soursop  0.001090  0.001110  0.001256  0.000000  0.036883
# Snow     0.000962  0.000981  0.001044  0.036883  0.000000

# %%
df_association
# Out:
#              Atwood  Lady Oracle  Rounder  Allan  Aurora  Soursop  \
# Atwood         0.00         0.17     0.28   0.16    0.25     0.05
# Lady Oracle    0.17         0.00     0.34   0.29    0.42     0.02
# Rounder        0.28         0.34     0.00   0.19    0.41     0.04
# Allan          0.16         0.29     0.19   0.00    0.13     0.03
# Aurora         0.25         0.42     0.41   0.13    0.00     0.00
# Soursop        0.05         0.02     0.04   0.03    0.00     0.00
# Fruit Salad    0.07         0.03     0.04   0.01    0.01     0.32
# Snow           0.06         0.05     0.03   0.04    0.01     0.11
#
#              Fruit Salad  Snow
# Atwood              0.07  0.06
# Lady Oracle         0.03  0.05
# Rounder             0.04  0.03
# Allan               0.01  0.04
# Aurora              0.01  0.01
# Soursop             0.32  0.11
# Fruit Salad         0.00  0.14
# Snow                0.14  0.00

# %%
np.fill_diagonal(df_association.values, 0)
df_association
# Out:
#              Atwood  Lady Oracle  Rounder  Allan  Aurora  Soursop  \
# Atwood         0.00         0.17     0.28   0.16    0.25     0.05
# Lady Oracle    0.17         0.00     0.34   0.29    0.42     0.02
# Rounder        0.28         0.34     0.00   0.19    0.41     0.04
# Allan          0.16         0.29     0.19   0.00    0.13     0.03
# Aurora         0.25         0.42     0.41   0.13    0.00     0.00
# Soursop        0.05         0.02     0.04   0.03    0.00     0.00
# Fruit Salad    0.07         0.03     0.04   0.01    0.01     0.32
# Snow           0.06         0.05     0.03   0.04    0.01     0.11
#
#              Fruit Salad  Snow
# Atwood              0.07  0.06
# Lady Oracle         0.03  0.05
# Rounder             0.04  0.03
# Allan               0.01  0.04
# Aurora              0.01  0.01
# Soursop             0.32  0.11
# Fruit Salad         0.00  0.14
# Snow                0.14  0.00

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4), layout="constrained")


adj_assoc = df_association.loc[whales_common, whales_common].values
adj_assoc = adj_assoc - np.diag(np.diag(adj_assoc)) # set diagonal to zero

sb.heatmap(df_dist.loc[whales_common, whales_common], cmap="coolwarm", center=0, ax=ax1) #, xticklabels=common_whales, yticklabels=common_whales,

sb.heatmap(df_association.loc[whales_common, whales_common], cmap="coolwarm", center=0, ax=ax2) #, xticklabels=common_whales, yticklabels=common_whales, ax=ax2)

ax1.set_title(f"dist vid {vid_number}")
ax2.set_title("association")

plt.show()

# %%
import numpy as np
from scipy.stats import pearsonr

# Example: two pandas DataFrames of same shape
x = df_dist.loc[whales_common, whales_common].values.flatten()
y = df_association.loc[whales_common, whales_common].values.flatten()

print(vid_number)
try:
    corr, pval = pearsonr(x, y)
    print(f'Correlation: {corr:.2f}, p-value: {pval:.2e}')
except Exception:
    pval = np.nan
    corr = np.nan
    print("not same length")

if len(whales_common) < 4:
    pval = np.nan
    corr = np.nan
    print("not enough whales")

p_values[vid_number] = pval
correlations[vid_number] = corr
# Out:
# 1688841618482_2
# Correlation: 0.65, p-value: 4.94e-04

# %%
ids_sorted = np.argsort(list(correlations.keys()))

vid_nums_sorted = np.array(list(correlations.keys()))[ids_sorted]

p_values_sorted = np.array(list(p_values.values()))[ids_sorted]
correlations_sorted = np.array(list(correlations.values()))[ids_sorted]

# %%
correlations_sorted
# Out:
# array([ 2.86456206e-01,  5.61435006e-02, -1.02343324e-01,             nan,
#        -1.37397040e-01,  3.54646647e-04,  3.03672574e-01,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,  1.89206404e-01,             nan,  3.72672171e-01,
#         4.33759144e-01,  6.45380797e-01])

# %%
fig, (ax, ax2) = plt.subplots(2, 1, sharex=True)

colors = ["C0"] * 4 + ["C1"] * 4 + ["C2"] * 8 + ["C3"] * 2
significant = [c if p < 0.05 else "none" for p,c in zip(p_values_sorted,colors)]

# sb.lineplot(p_values, ax=ax, marker="o")#, label="p-values",)
ax.scatter(vid_nums_sorted, p_values_sorted, edgecolors=colors, facecolors=significant)
    
ax.axhline(0.05, c="k", ls="--", label="significance threshold")
ax.legend()

plt.xticks(rotation=45, ha="right")

# sb.lineplot(correlations, ax=ax2, marker="o")#, label="correlations")
ax2.scatter(vid_nums_sorted, correlations_sorted, edgecolors=colors, facecolors=significant)

ax.set_yscale("log")

ax.set_ylabel("p-values")
ax2.set_ylabel("pearson correlation")

sb.despine()

ax.set_title("Corr. assocation birth vs non-birth")

ax.grid(axis="x")
ax2.grid(axis="x")

ax2.set_xlabel("Video number")

fig_name = f"assocation_birth_vs_nonbirth"
plt.savefig(f"{results_dir}{fig_name}.pdf", dpi=250, bbox_inches="tight", facecolor="w")
plt.savefig(f"{results_dir}{fig_name}.png", dpi=250, bbox_inches="tight", facecolor="w")


plt.show()
